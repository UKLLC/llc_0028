# %%
import os
import json
import numpy as np

# %%
study_variables = {}

# %% [markdown]
# ## ALSPAC m

# %%
study_variables['alspac_m'] = {}

#table name
study_variables['alspac_m']['table'] = 'ALSPAC_wave4m_v0001_20220531'

#covid yes or no
study_variables['alspac_m']['covid_yes_no'] = {}
study_variables['alspac_m']['covid_yes_no']['var'] = 'covid4m_1500'
study_variables['alspac_m']['covid_yes_no']['vals'] =   {0.0: 'No',
                                                         1.0: 'Yes, confirmed by positive swab test',
                                                         -1.0: 'Missing',
                                                         -10.0: 'Did not complete Q',
                                                         -11.0: 'Mother of trips/quads',
                                                         2.0: 'Yes, suspected by a doctor but not tested',
                                                         3.0: 'Yes, own suspicions',
                                                         -9.0: 'Missed COVID section 1',
                                                         -9999.0: 'Consent withdrawn'}
study_variables['alspac_m']['covid_yes_no']['harmonised'] = {2.0: 'Yes',
                                                             1.0: 'Yes',
                                                             3.0: 'Yes',
                                                             0.0: 'No',
                                                             np.nan: 'NA',}

#covid date
study_variables['alspac_m']['covid_date'] = {}
study_variables['alspac_m']['covid_date']['day'] = 'covid4m_1511'
study_variables['alspac_m']['covid_date']['month'] = 'covid4m_1512'
study_variables['alspac_m']['covid_date']['year'] = 'covid4m_1513'

#symptom reported
study_variables['alspac_m']['symptom_date'] = {}
study_variables['alspac_m']['symptom_date']['day'] = 'covid4m_9620'
study_variables['alspac_m']['symptom_date']['month'] = 'covid4m_9621'
study_variables['alspac_m']['symptom_date']['year'] = 'covid4m_9622'

#individual symptoms
study_variables['alspac_m']['symptoms'] = {'covid4m_1006': 'had a decrease in appetite',
                                             'covid4m_1016': 'had nausea and/or vomiting',
                                             'covid4m_1026': 'had diarrhoea',
                                             'covid4m_1036': 'had abdominal pain/tummy ache',
                                             'covid4m_1046': 'had runny nose',
                                             'covid4m_1056': 'had sneezing',
                                             'covid4m_1066': 'had blocked nose',
                                             'covid4m_1076': 'had sore eyes',
                                             'covid4m_1086': 'had loss of sense of smell',
                                             'covid4m_1096': 'had loss of sense of taste',
                                             'covid4m_1106': 'had sore throat',
                                             'covid4m_1116': 'had hoarse voice',
                                             'covid4m_1126': 'had headaches more often/worse than usual',
                                             'covid4m_1136': 'had dizziness',
                                             'covid4m_1146': 'had new persistent cough',
                                             'covid4m_1156': 'had tightness in the chest',
                                             'covid4m_1166': 'had chest pain',
                                             'covid4m_1176': 'had fever',
                                             'covid4m_1186': 'had chills',
                                             'covid4m_1196': 'had difficulty sleeping',
                                             'covid4m_1206': 'felt more tired than usual',
                                             'covid4m_1216': 'had severe fatigue',
                                             'covid4m_1226': 'had numbness or tingling',
                                             'covid4m_1236': 'had feeling of heaviness in arms or legs',
                                             'covid4m_1246': 'had achy muscles',
                                             'covid4m_1256': 'had shortness of breath',
                                             'covid4m_1266': 'had raised; red; itchy skin',
                                             'covid4m_1276': 'had sudden face/lip swelling',
                                             'covid4m_1286': 'had red/purple sores or blisters on feet',
                                             'covid4m_1296': 'had new hair loss',
                                             'covid4m_1306': 'had tender neck',
                                             'covid4m_1316': 'had swollen/painful joints',
                                             'covid4m_1326': 'had blood in urine'}

# %% [markdown]
# ## ALSPAC y

# %%
study_variables['alspac_y'] = {}

#table name
study_variables['alspac_y']['table'] = 'ALSPAC_wave4y_v0001_20220531'

#covid yes or no
study_variables['alspac_y']['covid_yes_no'] = {}
study_variables['alspac_y']['covid_yes_no']['var'] = 'covid4yp_1500'
study_variables['alspac_y']['covid_yes_no']['vals'] =   {0.0: 'No',
                                                         1.0: 'Yes, confirmed by positive swab test',
                                                         -1.0: 'Missing',
                                                         -10.0: 'Did not complete Q',
                                                         -11.0: 'Mother of trips/quads',
                                                         2.0: 'Yes, suspected by a doctor but not tested',
                                                         3.0: 'Yes, own suspicions',
                                                         -9.0: 'Missed COVID section 1',
                                                         -9999.0: 'Consent withdrawn'}
study_variables['alspac_y']['covid_yes_no']['harmonised'] = {2.0: 'Yes',
                                                             1.0: 'Yes',
                                                             3.0: 'Yes',
                                                             0.0: 'No',
                                                             np.nan: 'NA',}

#covid date
study_variables['alspac_y']['covid_date'] = {}
study_variables['alspac_y']['covid_date']['day'] = 'covid4yp_1511'
study_variables['alspac_y']['covid_date']['month'] = 'covid4yp_1512'
study_variables['alspac_y']['covid_date']['year'] = 'covid4yp_1513'

#symptom reported
study_variables['alspac_y']['symptom_date'] = {}
study_variables['alspac_y']['symptom_date']['day'] = 'covid4yp_9620'
study_variables['alspac_y']['symptom_date']['month'] = 'covid4yp_9621'
study_variables['alspac_y']['symptom_date']['year'] = 'covid4yp_9622'

#individual symptoms
study_variables['alspac_y']['symptoms'] = {'covid4yp_1006': 'had a decrease in appetite',
                                             'covid4yp_1016': 'had nausea and/or vomiting',
                                             'covid4yp_1026': 'had diarrhoea',
                                             'covid4yp_1036': 'had abdominal pain/tummy ache',
                                             'covid4yp_1046': 'had runny nose',
                                             'covid4yp_1056': 'had sneezing',
                                             'covid4yp_1066': 'had blocked nose',
                                             'covid4yp_1076': 'had sore eyes',
                                             'covid4yp_1086': 'had loss of sense of smell',
                                             'covid4yp_1096': 'had loss of sense of taste',
                                             'covid4yp_1106': 'had sore throat',
                                             'covid4yp_1116': 'had hoarse voice',
                                             'covid4yp_1126': 'had headaches more often/worse than usual',
                                             'covid4yp_1136': 'had dizziness',
                                             'covid4yp_1146': 'had new persistent cough',
                                             'covid4yp_1156': 'had tightness in the chest',
                                             'covid4yp_1166': 'had chest pain',
                                             'covid4yp_1176': 'had fever',
                                             'covid4yp_1186': 'had chills',
                                             'covid4yp_1196': 'had difficulty sleeping',
                                             'covid4yp_1206': 'felt more tired than usual',
                                             'covid4yp_1216': 'had severe fatigue',
                                             'covid4yp_1226': 'had numbness or tingling',
                                             'covid4yp_1236': 'had feeling of heaviness in arms or legs',
                                             'covid4yp_1246': 'had achy muscles',
                                             'covid4yp_1256': 'had shortness of breath',
                                             'covid4yp_1266': 'had raised; red; itchy skin',
                                             'covid4yp_1276': 'had sudden face/lip swelling',
                                             'covid4yp_1286': 'had red/purple sores or blisters on feet',
                                             'covid4yp_1296': 'had new hair loss',
                                             'covid4yp_1306': 'had tender neck',
                                             'covid4yp_1316': 'had swollen/painful joints',
                                             'covid4yp_1326': 'had blood in urine'}

# %% [markdown]
# ## BiB

# %%
study_variables['bib'] = {}

#table name
study_variables['bib']['table'] = 'BIB_CV_W2_v0001_20220302'

#covid yes or no
study_variables['bib']['covid_yes_no'] = {}
study_variables['bib']['covid_yes_no']['var'] = 'c19a2_cv_wt_expsymp'
study_variables['bib']['covid_yes_no']['vals'] =   {1.0: 'Yes, confirmed by a positive test',
                                                    2.0: 'Yes, suspected by a doctor but not tested',
                                                    3.0: 'Yes, my own suspicions',
                                                    4.0: 'No'}
study_variables['bib']['covid_yes_no']['harmonised'] = {2.0: 'Yes',
                                                        1.0: 'Yes',
                                                        3.0: 'Yes',
                                                        4.0: 'No',
                                                        np.nan: 'NA',}

#covid date
study_variables['bib']['covid_date'] = 'c19a2_cv_wt_sympwhn'


#symptom reported
study_variables['bib']['symptom_date'] = '15/09/2020'

#individual symptoms. Using symptoms reported for september 2020
study_variables['bib']['symptoms'] = {'c19a2_symp_abdo_7': 'Abdominal pain/tummy ache ',
                                         'c19a2_symp_ache_7': 'Achy muscles ',
                                         'c19a2_symp_app_7': 'Decrease in appetite ',
                                         'c19a2_symp_bnose_7': 'Blocked nose ',
                                         'c19a2_symp_bre_7': 'Shortness of breath ',
                                         'c19a2_symp_che_7': 'Chest pain ',
                                         'c19a2_symp_chills_7': 'Chills ',
                                         'c19a2_symp_coug_7': 'NEW persistent cough ',,
                                         'c19a2_symp_diar_7': 'Diarrhoea ',
                                         'c19a2_symp_dizz_7': 'Dizziness ',
                                         'c19a2_symp_eyes_7': 'Sore eyes ',
                                         'c19a2_symp_fatig_7': 'Severe fatigue ',
                                         'c19a2_symp_fev_7': 'Fever ',
                                         'c19a2_symp_head_7': 'Headache ',
                                         'c19a2_symp_heav_7': 'Feeling of heaviness in arms or legs ',
                                         'c19a2_symp_itch_7': 'Raised; red; itchy areas on the skin ',
                                         'c19a2_symp_nau_7': 'Nausea and/or vomiting ',
                                         'c19a2_symp_numb_7': 'Numbness or tingling somewhere in the body ',
                                         'c19a2_symp_rnose_7': 'Runny nose ',
                                         'c19a2_symp_slp_7': 'Difficulty sleeping ',
                                         'c19a2_symp_sneez_7': 'Sneezing ',
                                         'c19a2_symp_sore_7': 'Red/purple sores or blisters on your feet ',
                                         'c19a2_symp_swell_7': 'Sudden swelling of the face or lips',
                                         'c19a2_symp_throat_7': 'Sore throat ',
                                         'c19a2_symp_tig_7': 'Tightness in the chest ',
                                         'c19a2_symp_tired_7': 'Felt more tired than normal ',
                                         'c19a2_symp_voic_7': 'Hoarse voice '}

# %% [markdown]
# ## Track19

# %%
study_variables['track19'] = {}

#table name
study_variables['track19']['table'] = 'TRACKC19_baseline_v0001_20210915'

#covid yes or no
study_variables['track19']['covid_yes_no'] = {}
study_variables['track19']['covid_yes_no']['var'] = 'covidme'
study_variables['track19']['covid_yes_no']['vals'] =   {1.0: 'no',
                                                         2.0: 'yes, confirmed by a positiev test',
                                                         3.0: 'yes, suspected by a doctor but not tested',
                                                         4.0: 'yes, my own suspicions, but not seen by a doctor or tested',
                                                         999.0: "don't know / can't remember"}
study_variables['track19']['covid_yes_no']['harmonised'] = {2.0: 'Yes',
                                                             4.0: 'Yes',
                                                             3.0: 'Yes',
                                                             1.0: 'No',
                                                             np.nan: 'NA',
                                                             999.0: 'NA'}

#covid date
study_variables['track19']['covid_date'] = 'coviddate'


#symptom reported
study_variables['track19']['symptom_date'] = 'startdate'

#individual symptoms. Using symptoms reported for the last week
study_variables['track19']['symptoms'] = {'symptom1_wk': 'no cold or flu symptoms',
                                             'symptom10_wk': 'a loss of sense of smell or taste',
                                             'symptom11_wk': 'a sore throat',
                                             'symptom12_wk': 'a hoarse voice',
                                             'symptom13_wk': 'a headache (if more often or worse than usual)',
                                             'symptom14_wk': 'dizziness',
                                             'symptom15_wk': 'a new persistent cough',
                                             'symptom16_wk': 'tightness in the chest',
                                             'symptom17_wk': 'chest pain',
                                             'symptom18_wk': 'a fever (feeling too hot)',
                                             'symptom19_wk': 'chills (feeling too cold)',
                                             'symptom2_wk': 'a decrease in appetite',
                                             'symptom20_wk': 'difficulty sleeping',
                                             'symptom22_wk': 'severe fatigue (e.g. inability to get out of bed)',
                                             'symptom23_wk': 'numbness or tingling somewhere in the body',
                                             'symptom24_wk': 'a feeling of heaviness in arms or legs',
                                             'symptom25_wk': 'achy muscles',
                                             'symptom3_wk': 'nausea and/or vomiting',
                                             'symptom4_wk': 'diarrhoea',
                                             'symptom5_wk': 'abdominal pain/tummy ache',
                                             'symptom6_wk': 'a runny nose',
                                             'symptom7_wk': 'sneezing',
                                             'symptom8_wk': 'a blocked nose',
                                             'symptom9_wk': 'sore eyes'}

# %% [markdown]
# ## Twins - cope2

# %%
study_variables['twins'] = {}

#table name
study_variables['twins']['table'] = 'TWINSUK_COPE2_v0002_20220302'

#covid yes or no
study_variables['twins']['covid_yes_no'] = {}
study_variables['twins']['covid_yes_no']['var'] = 'b13'
study_variables['twins']['covid_yes_no']['vals'] = {0: 'No',
                                                    1: 'Yes, diagnosed and recovered or diagnosed and still ill ',
                                                    3: 'Not formally diagnosed but suspected and recovered ',
                                                    4: 'Not formally diagnosed but suspected and still ill ',
                                                    999905: 'Unable to determine (unclear answered given by the participant)',
                                                    999906: 'Question seen but not answered'}
study_variables['twins']['covid_yes_no']['harmonised'] = {0: 'No',
                                                         1: 'Yes',
                                                         3: 'Yes',
                                                         4: 'Yes',
                                                         999905: 'NA',
                                                         999906: 'NA'}

#covid date - when did symptoms start
study_variables['twins']['covid_date'] = 'b16_date'


#symptom reported - using symtpoms reported in June/July
study_variables['twins']['symptom_date'] = '01/07/2020'

#individual symptoms. Using symptoms reported for june 2020
study_variables['twins']['symptoms'] = {'b8a_3': ' Cold or flu symptoms ',
                                         'b8aa_3': ' Feeling of heaviness in arms or legs ',
                                         'b8ab_3': ' Strong muscle pains or aches ',
                                         'b8ac_3': ' Shaking or difficulty while walking ',
                                         'b8ad_3': ' Phlegm production/chesty cough ',
                                         'b8ae_3': ' Raised, red, itchy welts on the skin or sudden swelling of the face or lips ',
                                         'b8af_3': ' Red/purple sores or blisters on feet ',
                                         'b8ag_3': ' Confusion, disorientation or drowsiness ',
                                         'b8b_3': ' Decrease in appetite ',
                                         'b8c_3': ' Nausea and/or vomiting ',
                                         'b8d_3': ' Diarrhoea ',
                                         'b8e_3': ' Abdominal pain/stomach ache ',
                                         'b8f_3': ' Runny nose ',
                                         'b8g_3': ' Sneezing ',
                                         'b8h_3': ' Blocked nose ',
                                         'b8i_3': ' Unusual eye soreness or discomfort ',
                                         'b8j_3': ' Loss of sense of smell ',
                                         'b8k_3': ' Loss of sense of taste ',
                                         'b8l_3': ' Sore or painful throat ',
                                         'b8m_3': ' Hoarse voice ',
                                         'b8n_3': ' Headache ',
                                         'b8o_3': ' Dizziness, light',
                                         'b8p_3': ' Shortness of breath or trouble breathing affecting normal activities ',
                                         'b8q_3': ' New persistent cough ',
                                         'b8r_3': ' Tightness in the chest ',
                                         'b8s_3': ' Chest pain ',
                                         'b8t_3': ' Racing heart or palpitations ',
                                         'b8u_3': ' Fever ',
                                         'b8v_3': ' Chills (feeling too cold) ',
                                         'b8w_3': ' Difficulty sleeping ',
                                         'b8x_3': ' Felt more tired than normal ',
                                         'b8y_3': ' Severe fatigue ',
                                         'b8z_3': ' Numbness or tingling somewhere in the body ',
                                       #  'c45': ' Memory ',
                                       }

# %% [markdown]
# ## Twins - cope4

# %%
study_variables['twins'] = {}

#table name
study_variables['twins']['table'] = 'TWINSUK_COPE4_v0001_20230221'

#covid yes or no
study_variables['twins']['covid_yes_no'] = {}
study_variables['twins']['covid_yes_no']['var'] = 'q_b_3'
study_variables['twins']['covid_yes_no']['vals'] = {0: 'No',
                                                    1: 'Yes, confirmed by a positive test',
                                                    2: 'Yes, based on medical advice',
                                                    3: 'Yes, based on strong personal suspicion',
                                                    999901: 'Prefer not to say',
                                                    999902: 'Unsure',
                                                    999905: 'Unable to determine (unclear answer given by the participant)',
                                                    999906: 'No data available'}
study_variables['twins']['covid_yes_no']['harmonised'] = {0: 'No',
                                                         1: 'Yes',
                                                         2: 'Yes',
                                                         3: 'Yes',
                                                        999901: 'NA',
                                                        999902: 'NA',
                                                        999905: 'NA',
                                                        999906: 'NA'}
#covid date - date of first and re infection
study_variables['twins']['covid_date'] = ['q_b_4_1_text','q_b_9_1_text']


#symptom reported - using symtpoms reported in Feb/March 2021
study_variables['twins']['symptom_date'] = '01/03/2021'

#individual symptoms. Using symptoms reported for june 2020
study_variables['twins']['symptoms'] = {'q_b_1_chest_pain_3': 'Chest pain',
                                         'q_b_1_confusion_3': 'Confusion, disorientation or drowsiness',
                                         'q_b_1_decrease_appetite_3': 'Decrease in appetite',
                                         'q_b_1_diarrhoea_3': 'Diarrhoea',
                                         'q_b_1_fatigue_3': 'Unusual fatigue/feeling unusually tired',
                                         'q_b_1_feverish_3': 'Feeling Feverish',
                                         'q_b_1_headache_3': 'Headache',
                                         'q_b_1_muscle_pains_3': 'Unusual muscle pains or aches',
                                         'q_b_1_persistantcough_3': 'New persistent cough',
                                         'q_b_1_shortness_3': 'Shortness of breath or trouble breathing affecting normal activities',
                                         'q_b_1b_fever_3': 'Fever',
                                         'q_b_1c_chills_3': 'Chills (feeling too cold)',
                                         'q_b_1d_loss_smell_3': 'Loss or change in sense of smell',
                                         'q_b_1e_loss_taste_3': 'Loss or change in sense of taste',
                                         'q_b_1f_runny_nose_3': 'Runny nose',
                                         'q_b_1g_sore_throat_3': 'Sore or painful throat'}

study_variables['twins']['functional_limitation'] = 'q_b_12'

# %% [markdown]
# # CLS studies

# %% [markdown]
# ## SABRE

# %%
study_variables['sabre'] = {}

#table name
study_variables['sabre']['table'] = 'SABRE_COVID_WAVE3_v0002_20220118'

#covid yes or no
study_variables['sabre']['covid_yes_no'] = {}
study_variables['sabre']['covid_yes_no']['var'] = 'cw3_covid19'
study_variables['sabre']['covid_yes_no']['vals'] = {
                                                    1.: 'Yes, confirmed by a positive test',
                                                    2.: 'Yes, based on strong personal suspicion or medical advice',
                                                    3.: 'Unsure',
                                                    4.: 'No',
                                                    -9.: 'Dont want to answer',
                                                    -8.: 'Dont know',
                                                    -7.: 'No NHSD questionnaire',
                                                    -1.: 'Not applicable'}
study_variables['sabre']['covid_yes_no']['harmonised'] = {
                                                         1.0: 'Yes',
                                                         2.0: 'Yes',
                                                         3.0: 'No',
                                                         4.0: 'No',
                                                         -9.0: 'NA',
                                                         -8.0: 'NA',
                                                         -7.0: 'NA'}

#covid date - when did symptoms start
study_variables['sabre']['covid_date'] = 'cw3_covid19pos'


#symptom reported - using symtpoms reported 2 weeks prior to survey completion
study_variables['sabre']['symptom_date'] = {}
study_variables['sabre']['symptom_date']['day'] = 'cw3_covdtday'
study_variables['sabre']['symptom_date']['month'] = 'cw3_covdtmnth'
study_variables['sabre']['symptom_date']['year'] = 2021

#individual symptoms. Using symptoms reported 2 weeks prior to survey
study_variables['sabre']['symptoms'] = {'cw3_covidsympt_1' :'Past_2_wks_FEVER',
                                        'cw3_covidsympt_10':'Past_2_wks_MUSCLE_OR_BODY_ACHES',
                                        'cw3_covidsympt_11':'Past_2_wks_FATIGUE',
                                        'cw3_covidsympt_12':'Past_2_wks_LOOSEMOT_DIARRHOEA',
                                        'cw3_covidsympt_13':'Past_2_wks_LOSS_OF_SMELL',
                                        'cw3_covidsympt_14':'Past_2_wks_LOSS_OF_TASTE',
                                        'cw3_covidsympt_16':'Past_2_wks_VOMITING',
                                        'cw3_covidsympt_17':'Past_2_wks_SKIN_RASH',
                                        'cw3_covidsympt_18':'Past_2_wks_SNEEZING',
                                        'cw3_covidsympt_19':'Past_2_wks_HEADACHES',
                                        'cw3_covidsympt_2':'Past_2_wks_COUGH_DRY',
                                        'cw3_covidsympt_20':'Past_2_wks_OTHER',
                                        'cw3_covidsympt_23':'Past_2_wks_NONE',
                                        'cw3_covidsympt_3':'Past_2_wks_COUGH_MUCUS_OR_PHLEGM',
                                        'cw3_covidsympt_4':'Past_2_wks_SORE_THROAT',
                                        'cw3_covidsympt_5':'Past_2_wks_CHEST_TIGHTNESS',
                                        'cw3_covidsympt_6':'Past_2_wks_SHORTNESS_OF_BREATH',
                                        'cw3_covidsympt_7':'Past_2_wks_RUNNY_NOSE',
                                        'cw3_covidsympt_8':'Past_2_wks_NASAL_CONGESTION',
                                        'cw3_fatgrid_8':'EXTRA_DIFFICULTY_CONCENTRATING',
                                        'cw3_memory':'EXTRA_MEMORY',
                                        }

study_variables['sabre']['functional_limitation'] = 'cw3_covfunc'

# %%
study_variables['nhsd46'] = {}

#table name
study_variables['nhsd46']['table'] = 'NSHD46_COVIDW3WEB_v0001_20211101'

#covid yes or no
study_variables['nhsd46']['covid_yes_no'] = {}
study_variables['nhsd46']['covid_yes_no']['var'] = 'cw3_covid19'
study_variables['nhsd46']['covid_yes_no']['vals'] = {
                                                    1.: 'Yes, confirmed by a positive test',
                                                    2.: 'Yes, based on strong personal suspicion or medical advice',
                                                    3.: 'Unsure',
                                                    4.: 'No',
                                                    -9.: 'Dont want to answer',
                                                    -8.: 'Dont know',
                                                    -7.: 'No NHSD questionnaire',
                                                    -1.: 'Not applicable'}
study_variables['nhsd46']['covid_yes_no']['harmonised'] = {
                                                         1.0: 'Yes',
                                                         2.0: 'Yes',
                                                         3.0: 'No',
                                                         4.0: 'No',
                                                         -9.0: 'NA',
                                                         -8.0: 'NA',
                                                         -7.0: 'NA'}

#covid date - when did symptoms start
study_variables['nhsd46']['covid_date'] = 'cw3_covid19pos'


#symptom reported - using symtpoms reported 2 weeks prior to survey completion
study_variables['nhsd46']['symptom_date'] = {}
study_variables['nhsd46']['symptom_date']['day'] = 'cw3_enddated'
study_variables['nhsd46']['symptom_date']['month'] = 'cw3_enddatem'
study_variables['nhsd46']['symptom_date']['year'] = 2021

#individual symptoms. Using symptoms reported 2 weeks prior to survey
study_variables['nhsd46']['symptoms'] = {'cw3_covidsympt_1' :'Past_2_wks_FEVER',
                                        'cw3_covidsympt_10':'Past_2_wks_MUSCLE_OR_BODY_ACHES',
                                        'cw3_covidsympt_11':'Past_2_wks_FATIGUE',
                                        'cw3_covidsympt_12':'Past_2_wks_LOOSEMOT_DIARRHOEA',
                                        'cw3_covidsympt_13':'Past_2_wks_LOSS_OF_SMELL',
                                        'cw3_covidsympt_14':'Past_2_wks_LOSS_OF_TASTE',
                                        'cw3_covidsympt_16':'Past_2_wks_VOMITING',
                                        'cw3_covidsympt_17':'Past_2_wks_SKIN_RASH',
                                        'cw3_covidsympt_18':'Past_2_wks_SNEEZING',
                                        'cw3_covidsympt_19':'Past_2_wks_HEADACHES',
                                        'cw3_covidsympt_2':'Past_2_wks_COUGH_DRY',
                                        'cw3_covidsympt_20':'Past_2_wks_OTHER',
                                        'cw3_covidsympt_23':'Past_2_wks_NONE',
                                        'cw3_covidsympt_3':'Past_2_wks_COUGH_MUCUS_OR_PHLEGM',
                                        'cw3_covidsympt_4':'Past_2_wks_SORE_THROAT',
                                        'cw3_covidsympt_5':'Past_2_wks_CHEST_TIGHTNESS',
                                        'cw3_covidsympt_6':'Past_2_wks_SHORTNESS_OF_BREATH',
                                        'cw3_covidsympt_7':'Past_2_wks_RUNNY_NOSE',
                                        'cw3_covidsympt_8':'Past_2_wks_NASAL_CONGESTION',
                                        'cw3_fatgrid_8':'EXTRA_DIFFICULTY_CONCENTRATING',
                                        'cw3_memory':'EXTRA_MEMORY',
                                        }

study_variables['nhsd46']['functional_limitation'] = 'cw3_covfunc'

# %%
study_variables['nextstep'] = {}

#table name
study_variables['nextstep']['table'] = 'NEXTSTEP_COVID_w3_v0001_20211101'

#covid yes or no
study_variables['nextstep']['covid_yes_no'] = {}
study_variables['nextstep']['covid_yes_no']['var'] = 'cw3_covid19'
study_variables['nextstep']['covid_yes_no']['vals'] = {
                                                    1.: 'Yes, confirmed by a positive test',
                                                    2.: 'Yes, based on strong personal suspicion or medical advice',
                                                    3.: 'Unsure',
                                                    4.: 'No',
                                                    -9.: 'Dont want to answer',
                                                    -8.: 'Dont know',
                                                    -7.: 'No NHSD questionnaire',
                                                    -1.: 'Not applicable'}
study_variables['nextstep']['covid_yes_no']['harmonised'] = {
                                                         1.0: 'Yes',
                                                         2.0: 'Yes',
                                                         3.0: 'No',
                                                         4.0: 'No',
                                                         -9.0: 'NA',
                                                         -8.0: 'NA',
                                                         -7.0: 'NA'}

#covid date - when did symptoms start
study_variables['nextstep']['covid_date'] = 'cw3_covid19pos'


#symptom reported - using symtpoms reported 2 weeks prior to survey completion
study_variables['nextstep']['symptom_date'] = {}
study_variables['nextstep']['symptom_date']['day'] = 'cw3_enddated'
study_variables['nextstep']['symptom_date']['month'] = 'cw3_enddatem'
study_variables['nextstep']['symptom_date']['year'] = 2021

#individual symptoms. Using symptoms reported 2 weeks prior to survey
study_variables['nextstep']['symptoms'] = {'cw3_covidsympt_1' :'Past_2_wks_FEVER',
                                        'cw3_covidsympt_10':'Past_2_wks_MUSCLE_OR_BODY_ACHES',
                                        'cw3_covidsympt_11':'Past_2_wks_FATIGUE',
                                        'cw3_covidsympt_12':'Past_2_wks_LOOSEMOT_DIARRHOEA',
                                        'cw3_covidsympt_13':'Past_2_wks_LOSS_OF_SMELL',
                                        'cw3_covidsympt_14':'Past_2_wks_LOSS_OF_TASTE',
                                        'cw3_covidsympt_16':'Past_2_wks_VOMITING',
                                        'cw3_covidsympt_17':'Past_2_wks_SKIN_RASH',
                                        'cw3_covidsympt_18':'Past_2_wks_SNEEZING',
                                        'cw3_covidsympt_19':'Past_2_wks_HEADACHES',
                                        'cw3_covidsympt_2':'Past_2_wks_COUGH_DRY',
                                        'cw3_covidsympt_20':'Past_2_wks_OTHER',
                                        'cw3_covidsympt_23':'Past_2_wks_NONE',
                                        'cw3_covidsympt_3':'Past_2_wks_COUGH_MUCUS_OR_PHLEGM',
                                        'cw3_covidsympt_4':'Past_2_wks_SORE_THROAT',
                                        'cw3_covidsympt_5':'Past_2_wks_CHEST_TIGHTNESS',
                                        'cw3_covidsympt_6':'Past_2_wks_SHORTNESS_OF_BREATH',
                                        'cw3_covidsympt_7':'Past_2_wks_RUNNY_NOSE',
                                        'cw3_covidsympt_8':'Past_2_wks_NASAL_CONGESTION',
                                        'cw3_fatgrid_8':'EXTRA_DIFFICULTY_CONCENTRATING',
                                        'cw3_memory':'EXTRA_MEMORY',
                                        }

study_variables['nextstep']['functional_limitation'] = 'cw3_covfunc'

# %%
study_variables['mcs'] = {}

#table name
study_variables['mcs']['table'] = 'MCS_COVID_w3_v0001_20211101'

#covid yes or no
study_variables['mcs']['covid_yes_no'] = {}
study_variables['mcs']['covid_yes_no']['var'] = 'cw3_covid19'
study_variables['mcs']['covid_yes_no']['vals'] = {
                                                    1.: 'Yes, confirmed by a positive test',
                                                    2.: 'Yes, based on strong personal suspicion or medical advice',
                                                    3.: 'Unsure',
                                                    4.: 'No',
                                                    -9.: 'Dont want to answer',
                                                    -8.: 'Dont know',
                                                    -7.: 'No NHSD questionnaire',
                                                    -1.: 'Not applicable'}
study_variables['mcs']['covid_yes_no']['harmonised'] = {
                                                         1.0: 'Yes',
                                                         2.0: 'Yes',
                                                         3.0: 'No',
                                                         4.0: 'No',
                                                         -9.0: 'NA',
                                                         -8.0: 'NA',
                                                         -7.0: 'NA'}

#covid date - when did symptoms start
study_variables['mcs']['covid_date'] = 'cw3_covid19pos'


#symptom reported - using symtpoms reported 2 weeks prior to survey completion
study_variables['mcs']['symptom_date'] = {}
study_variables['mcs']['symptom_date']['day'] = 'cw3_enddated'
study_variables['mcs']['symptom_date']['month'] = 'cw3_enddatem'
study_variables['mcs']['symptom_date']['year'] = 2021

#individual symptoms. Using symptoms reported 2 weeks prior to survey
study_variables['mcs']['symptoms'] = {'cw3_covidsympt_1' :'Past_2_wks_FEVER',
                                        'cw3_covidsympt_10':'Past_2_wks_MUSCLE_OR_BODY_ACHES',
                                        'cw3_covidsympt_11':'Past_2_wks_FATIGUE',
                                        'cw3_covidsympt_12':'Past_2_wks_LOOSEMOT_DIARRHOEA',
                                        'cw3_covidsympt_13':'Past_2_wks_LOSS_OF_SMELL',
                                        'cw3_covidsympt_14':'Past_2_wks_LOSS_OF_TASTE',
                                        'cw3_covidsympt_16':'Past_2_wks_VOMITING',
                                        'cw3_covidsympt_17':'Past_2_wks_SKIN_RASH',
                                        'cw3_covidsympt_18':'Past_2_wks_SNEEZING',
                                        'cw3_covidsympt_19':'Past_2_wks_HEADACHES',
                                        'cw3_covidsympt_2':'Past_2_wks_COUGH_DRY',
                                        'cw3_covidsympt_20':'Past_2_wks_OTHER',
                                        'cw3_covidsympt_23':'Past_2_wks_NONE',
                                        'cw3_covidsympt_3':'Past_2_wks_COUGH_MUCUS_OR_PHLEGM',
                                        'cw3_covidsympt_4':'Past_2_wks_SORE_THROAT',
                                        'cw3_covidsympt_5':'Past_2_wks_CHEST_TIGHTNESS',
                                        'cw3_covidsympt_6':'Past_2_wks_SHORTNESS_OF_BREATH',
                                        'cw3_covidsympt_7':'Past_2_wks_RUNNY_NOSE',
                                        'cw3_covidsympt_8':'Past_2_wks_NASAL_CONGESTION',
                                        'cw3_fatgrid_8':'EXTRA_DIFFICULTY_CONCENTRATING',
                                        'cw3_memory':'EXTRA_MEMORY',
                                        }
study_variables['mcs']['functional_limitation'] = 'cw3_covfunc'

# %%
study_variables['bcs70'] = {}

#table name
study_variables['bcs70']['table'] = 'BCS70_COVID_w3_v0001_20211101'

#covid yes or no
study_variables['bcs70']['covid_yes_no'] = {}
study_variables['bcs70']['covid_yes_no']['var'] = 'cw3_covid19'
study_variables['bcs70']['covid_yes_no']['vals'] = {
                                                    1.: 'Yes, confirmed by a positive test',
                                                    2.: 'Yes, based on strong personal suspicion or medical advice',
                                                    3.: 'Unsure',
                                                    4.: 'No',
                                                    -9.: 'Dont want to answer',
                                                    -8.: 'Dont know',
                                                    -7.: 'No NHSD questionnaire',
                                                    -1.: 'Not applicable'}
study_variables['bcs70']['covid_yes_no']['harmonised'] = {
                                                         1.0: 'Yes',
                                                         2.0: 'Yes',
                                                         3.0: 'No',
                                                         4.0: 'No',
                                                         -9.0: 'NA',
                                                         -8.0: 'NA',
                                                         -7.0: 'NA'}

#covid date - when did symptoms start
study_variables['bcs70']['covid_date'] = 'cw3_covid19pos'


#symptom reported - using symtpoms reported 2 weeks prior to survey completion
study_variables['bcs70']['symptom_date'] = {}
study_variables['bcs70']['symptom_date']['day'] = 'cw3_enddated'
study_variables['bcs70']['symptom_date']['month'] = 'cw3_enddatem'
study_variables['bcs70']['symptom_date']['year'] = 2021

#individual symptoms. Using symptoms reported 2 weeks prior to survey
study_variables['bcs70']['symptoms'] = {'cw3_covidsympt_1' :'Past_2_wks_FEVER',
                                        'cw3_covidsympt_10':'Past_2_wks_MUSCLE_OR_BODY_ACHES',
                                        'cw3_covidsympt_11':'Past_2_wks_FATIGUE',
                                        'cw3_covidsympt_12':'Past_2_wks_LOOSEMOT_DIARRHOEA',
                                        'cw3_covidsympt_13':'Past_2_wks_LOSS_OF_SMELL',
                                        'cw3_covidsympt_14':'Past_2_wks_LOSS_OF_TASTE',
                                        'cw3_covidsympt_16':'Past_2_wks_VOMITING',
                                        'cw3_covidsympt_17':'Past_2_wks_SKIN_RASH',
                                        'cw3_covidsympt_18':'Past_2_wks_SNEEZING',
                                        'cw3_covidsympt_19':'Past_2_wks_HEADACHES',
                                        'cw3_covidsympt_2':'Past_2_wks_COUGH_DRY',
                                        'cw3_covidsympt_20':'Past_2_wks_OTHER',
                                        'cw3_covidsympt_23':'Past_2_wks_NONE',
                                        'cw3_covidsympt_3':'Past_2_wks_COUGH_MUCUS_OR_PHLEGM',
                                        'cw3_covidsympt_4':'Past_2_wks_SORE_THROAT',
                                        'cw3_covidsympt_5':'Past_2_wks_CHEST_TIGHTNESS',
                                        'cw3_covidsympt_6':'Past_2_wks_SHORTNESS_OF_BREATH',
                                        'cw3_covidsympt_7':'Past_2_wks_RUNNY_NOSE',
                                        'cw3_covidsympt_8':'Past_2_wks_NASAL_CONGESTION',
                                        'cw3_fatgrid_8':'EXTRA_DIFFICULTY_CONCENTRATING',
                                        'cw3_memory':'EXTRA_MEMORY',
                                        }

study_variables['bcs70']['functional_limitation'] = 'cw3_covfunc'

# %%
study_variables['ncds'] = {}

#table name
study_variables['ncds']['table'] = 'NCDS58_COVID_w3_v0001_20211101'

#covid yes or no
study_variables['ncds']['covid_yes_no'] = {}
study_variables['ncds']['covid_yes_no']['var'] = 'cw3_covid19'
study_variables['ncds']['covid_yes_no']['vals'] = {
                                                    1.: 'Yes, confirmed by a positive test',
                                                    2.: 'Yes, based on strong personal suspicion or medical advice',
                                                    3.: 'Unsure',
                                                    4.: 'No',
                                                    -9.: 'Dont want to answer',
                                                    -8.: 'Dont know',
                                                    -7.: 'No NHSD questionnaire',
                                                    -1.: 'Not applicable'}
study_variables['ncds']['covid_yes_no']['harmonised'] = {
                                                         1.0: 'Yes',
                                                         2.0: 'Yes',
                                                         3.0: 'No',
                                                         4.0: 'No',
                                                         -9.0: 'NA',
                                                         -8.0: 'NA',
                                                         -7.0: 'NA'}

#covid date - when did symptoms start
study_variables['ncds']['covid_date'] = 'cw3_covid19pos'


#symptom reported - using symtpoms reported 2 weeks prior to survey completion
study_variables['ncds']['symptom_date'] = {}
study_variables['ncds']['symptom_date']['day'] = 'cw3_enddated'
study_variables['ncds']['symptom_date']['month'] = 'cw3_enddatem'
study_variables['ncds']['symptom_date']['year'] = 2021

#individual symptoms. Using symptoms reported 2 weeks prior to survey
study_variables['ncds']['symptoms'] = {'cw3_covidsympt_1' :'Past_2_wks_FEVER',
                                        'cw3_covidsympt_10':'Past_2_wks_MUSCLE_OR_BODY_ACHES',
                                        'cw3_covidsympt_11':'Past_2_wks_FATIGUE',
                                        'cw3_covidsympt_12':'Past_2_wks_LOOSEMOT_DIARRHOEA',
                                        'cw3_covidsympt_13':'Past_2_wks_LOSS_OF_SMELL',
                                        'cw3_covidsympt_14':'Past_2_wks_LOSS_OF_TASTE',
                                        'cw3_covidsympt_16':'Past_2_wks_VOMITING',
                                        'cw3_covidsympt_17':'Past_2_wks_SKIN_RASH',
                                        'cw3_covidsympt_18':'Past_2_wks_SNEEZING',
                                        'cw3_covidsympt_19':'Past_2_wks_HEADACHES',
                                        'cw3_covidsympt_2':'Past_2_wks_COUGH_DRY',
                                        'cw3_covidsympt_20':'Past_2_wks_OTHER',
                                        'cw3_covidsympt_23':'Past_2_wks_NONE',
                                        'cw3_covidsympt_3':'Past_2_wks_COUGH_MUCUS_OR_PHLEGM',
                                        'cw3_covidsympt_4':'Past_2_wks_SORE_THROAT',
                                        'cw3_covidsympt_5':'Past_2_wks_CHEST_TIGHTNESS',
                                        'cw3_covidsympt_6':'Past_2_wks_SHORTNESS_OF_BREATH',
                                        'cw3_covidsympt_7':'Past_2_wks_RUNNY_NOSE',
                                        'cw3_covidsympt_8':'Past_2_wks_NASAL_CONGESTION',
                                        'cw3_fatgrid_8':'EXTRA_DIFFICULTY_CONCENTRATING',
                                        'cw3_memory':'EXTRA_MEMORY',
                                        }

study_variables['ncds']['functional_limitation'] = 'cw3_covfunc'

# %% [markdown]
# ## Save

# %%
#make json directory if it doesnt exist
if 'json' not in os.listdir():   
    os.mkdir('json')

#save dict to directory 
with open(f'json/llc_0028_vardict_data_v2.json', 'w') as f:
    json.dump(study_variables,f)
