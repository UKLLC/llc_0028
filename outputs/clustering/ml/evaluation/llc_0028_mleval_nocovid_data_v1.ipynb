# %% [markdown]
# # Evaluation of ML clustering algorithms: No COVID

# %% [markdown]
# This notebook contains plots that evaluate the performance of ML clustering algorithms. For each study, two algorithms (DBSCAN and Agglomerative) have been applied to self-reported symptom data for a range of parameter values. The parameter varied for DBSCAN is 'eps' and the parameter varied for Agglomerative is 'N clusters'.
#
# For each algorithm, and each study, there is a plot displaying the algorithm's performance over a range of parameter values. The evaluation metrics (DB Index and Silhouette Coefficient) are described below. In addition, we've recorded the proportion of study participants not assigned to a cluster (i.e. marked as 'noise' by the algorithm) for each parameter value. Left hand plots show  variation in these evaluation metrics with parameter value. Right hand plots show sizes of clusters, as a fraction of sample size, for each parameter value.

# %% [markdown]
# ## Selecting the best parameters

# %% [markdown]
# **Silhouette Score**
#
# $$ S = \frac{b-a}{\max(a,b)} $$
#
# - $a$: mean distance between points within a cluster
# - $b$: mean distance between a point and points in the nearest cluster
#
# Bounded between $-1$ and $1$.
#
# - $s=-1$ indicates incorrect clustering
# - $s=0$ indicates overlapping clusters
# - $s=1$ indicates dense, well seperated clusters
#
# **Davies Bouldin Index**
#
# The average similarity between each cluster and its most similar one, averaged over all clusters.
#
# $$ DB = \frac{1}{k} \sum_{i=1}^{k} \max_{i \neq j} R_{i,j} $$
#
# where
#
# $$ R_{i,j} = \frac{s_i + s_j}{d_{i,j}} $$
#
# - $k$: the number of clusters
# - $s_i$: the average distance between each point in cluster $i$ and the cluster centroid
# - $d_{i,j}$: the distance between the centroids of cluster $i$ and $j$
#
# Low values indicate a better partitioning of the data
#
# **Proportion of outliers**
#
# As we are forcing a minimum cluster size, not all datapoints will be assigned to a cluster. Those not assigned are described as outliers.
#
#
#
# ### Rules
#
# 1. maximise S (elbow)
# 2. minimise DB (elbow)
# 3. where possible, keep % outliers < 40
#
#
# #### Edge cases
#
# - If its not clear which parameter is best, ensure $S > 0$ while minimising % outliers
#
# - Where elbows occur for different parameter values in each metric, take the average of elbow parameter values

# %%
# %run llc_0028_evalfuncs_syntax_v1.ipynb

# %%
os.chdir('S:/LLC_0028/data/clustering/')
if 'figures' not in os.listdir():
    os.mkdir('figures')

# %%
algs = ['d', #DBSCAN - jaccard
       'dc', #DBSCAN - cosine
       'h',  #Agglomerative - jaccard
       'hc', #Agglomerative - cosine
       ]
sample = 'no'

# %%
# create df to store best params for each study and algorithm family

results = pd.DataFrame()

# %% [markdown]
# ## ALSPAC

# %% [markdown]
# ### Core symptom set

# %% [markdown]
# #### DBSCAN

# %%
study= sample + '_alspac'
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.3, 'type':'core'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 25, 'type':'core'}, ignore_index=True)

# %% [markdown]
# ### Maximal symptom set

# %% [markdown]
# #### DBSCAN

# %%
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.35, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 24, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# ### No results

# %% [markdown]
# ## BIB

# %% [markdown]
# ### Core symptom set

# %% [markdown]
# #### DBSCAN

# %%
study= sample + '_bib'
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.25, 'type':'core'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 21, 'type':'core'}, ignore_index=True)

# %% [markdown]
# ### Maximal symptom set

# %% [markdown]
# #### DBSCAN

# %%
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.4, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 15, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# ## NCDS

# %% [markdown]
# ### Core symptom set

# %% [markdown]
# #### DBSCAN

# %%
study=sample + '_ncds'
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.35, 'type':'core'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 29, 'type':'core'}, ignore_index=True)

# %% [markdown]
# ### Maximal symptom set

# %% [markdown]
# #### DBSCAN

# %%
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.35, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 29, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# ## MCS

# %% [markdown]
# ### Core symptom set

# %% [markdown]
# #### DBSCAN

# %%
study=sample + '_mcs'
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.25, 'type':'core'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 29, 'type':'core'}, ignore_index=True)

# %% [markdown]
# ### Maximal symptom set

# %% [markdown]
# #### DBSCAN

# %%
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.35, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 16, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# ## BCS70

# %% [markdown]
# ### Core symptom set

# %% [markdown]
# #### DBSCAN

# %%
study=sample + '_bcs70'
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.35, 'type':'core'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 19, 'type':'core'}, ignore_index=True)

# %% [markdown]
# ### Maximal symptom set

# %% [markdown]
# #### DBSCAN

# %%
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.35, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 17, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# ## Twins

# %% [markdown]
# ### Core symptom set

# %% [markdown]
# #### DBSCAN

# %%
study=sample + '_twins'
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.25, 'type':'core'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 17, 'type':'core'}, ignore_index=True)

# %% [markdown]
# ### Maximal symptom set

# %% [markdown]
# #### DBSCAN

# %% [raw]
# #loop over algorithms
# for algorithm in algs[:1]:
#
#     plot_eval(study, algorithm)

# %% [raw]
# #append best to results
#
# results = results.append({'study': study, 'algorithm': 'd', 'param': 0.5, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 22, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# ## NextStep

# %% [markdown]
# ### Core symptom set

# %% [markdown]
# #### DBSCAN

# %%
study=sample + '_nextstep'
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.25, 'type':'core'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 17, 'type':'core'}, ignore_index=True)

# %% [markdown]
# ### Maximal symptom set

# %% [markdown]
# #### DBSCAN

# %%
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.25, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 16, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# ## Track19

# %% [markdown]
# ### Core symptom set

# %% [markdown]
# #### DBSCAN

# %%
study=sample + '_track19'
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.35, 'type':'core'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 14, 'type':'core'}, ignore_index=True)

# %% [markdown]
# ### Maximal symptom set

# %% [markdown]
# #### DBSCAN

# %%
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.25, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 20, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# ## NHSD 46

# %% [markdown]
# ### Core symptom set

# %% [markdown]
# #### DBSCAN

# %%
study=sample + '_nhsd46'
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.25, 'type':'core'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 27, 'type':'core'}, ignore_index=True)

# %% [markdown]
# ### Maximal symptom set

# %% [markdown]
# #### DBSCAN

# %%
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.35, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 25, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# ## Pooled 7

# %% [markdown]
# ### Core symptom set

# %% [markdown]
# #### DBSCAN

# %%
study=sample + '_pooled7'
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.25, 'type':'core'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 20, 'type':'core'}, ignore_index=True)

# %% [markdown]
# ### Maximal symptom set

# %% [markdown]
# #### DBSCAN

# %%
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.25, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 25, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# ## Pooled All

# %% [markdown]
# ### Core symptom set

# %% [markdown]
# #### DBSCAN

# %%
study=sample + '_pooledall'
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.25, 'type':'core'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm, core=True)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 15, 'type':'core'}, ignore_index=True)

# %% [markdown]
# ### Maximal symptom set

# %% [markdown]
# #### DBSCAN

# %%
#loop over algorithms
for algorithm in algs[:1]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'd', 'param': 0.25, 'type':'maximal'}, ignore_index=True)

# %% [markdown]
# #### Agglomerative

# %%
#loop over algorithms
for algorithm in algs[2:3]:
        
    plot_eval(study, algorithm)

# %%
#append best to results

results = results.append({'study': study, 'algorithm': 'h', 'param': 27, 'type':'maximal'}, ignore_index=True)

# %%
results.to_csv(f'./results/llc_0028_best_params_ml_{sample}_v1.csv')
