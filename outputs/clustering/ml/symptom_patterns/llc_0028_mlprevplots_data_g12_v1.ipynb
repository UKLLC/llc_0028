# %% [markdown]
# # Prevalence plots: Covid > 12 weeks ago

# %% [markdown]
# This notebook contains a series of heatmaps to visualise patterns of self reported symptoms within clusters identified by DBSCAN and Agglomerative algorithms (see `llc_0028_mleval_g12_data_v1.ipynb`).
#
# The color scale in each figure represents the proportion of participants within each cluster that reported each symptom. Cluster sizes are all $\geq$ 5% of study size. For this sample, our smallest study has $>$ 300 participants, therefore these values are not disclosive.
#
# For the final set of plots (`pooled*`), while some clusters are less than 5% of the sample, this represents results from combining all studies into a single dataset, with over 2,000 participants. Therefore these numbers, although smaller than 5%, are also not disclosive.

# %%
# %run llc_0028_evalfuncs_syntax_v1.ipynb

# %%
os.chdir('S:/LLC_0028/data/clustering/')
sample = 'g12'
covid_status=2

# %%
results = pd.read_csv(f'./results/llc_0028_best_params_ml_{sample}_v1.csv',index_col=0)

# %% [markdown]
# ## ALSPAC

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %% [raw]
# study = 'alspac'
# study_f =sample +  '_' + study
#
# params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
# algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# #### Agglomerative

# %% [raw]
# params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
# algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %% [raw]
# params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
# algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# #### Agglomerative

# %% [raw]
# params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
# algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# ## BIB

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %% [raw]
# study = 'bib'
# study_f = sample + '_bib'
#
# params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
# algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# #### Agglomerative

# %% [raw]
# params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
# algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %% [raw]
# params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
# algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# #### Agglomerative

# %% [raw]
# params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
# algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# ## NCDS

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'ncds'
study_f = sample + '_' + study

params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 54.0 % of sample
#
# Cluster 1
# 15.0 % of sample
#
# Cluster 2
# 31.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 39.0 % of sample
#
# Cluster 1
# 6.0 % of sample
#
# Cluster 2
# 9.0 % of sample
#
# Cluster 3
# 22.0 % of sample
#
# Cluster 4
# 11.0 % of sample
#
# Cluster 5
# 7.0 % of sample
#
# Cluster 6
# 5.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 69.0 % of sample
#
# Cluster 1
# 18.0 % of sample
#
# Cluster 2
# 14.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 10.0 % of sample
#
# Cluster 1
# 12.0 % of sample
#
# Cluster 2 - unassigned
# 29.0 % of sample
#
# Cluster 3
# 11.0 % of sample
#
# Cluster 4
# 24.0 % of sample
#
# Cluster 5
# 9.0 % of sample
#
# Cluster 6
# 5.0 % of sample

# %% [markdown]
# ## MCS

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'mcs'
study_f = sample + '_' + study

params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 85.0 % of sample
#
# Cluster 1
# 8.0 % of sample
#
# Cluster 2
# 7.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 43.0 % of sample
#
# Cluster 1
# 8.0 % of sample
#
# Cluster 2 - unassigned
# 19.0 % of sample
#
# Cluster 3
# 9.0 % of sample
#
# Cluster 4
# 16.0 % of sample
#
# Cluster 5
# 6.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 64.0 % of sample
#
# Cluster 1
# 16.0 % of sample
#
# Cluster 2
# 7.0 % of sample
#
# Cluster 3
# 10.0 % of sample
#
# Cluster 4
# 2.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 33.0 % of sample
#
# Cluster 1
# 11.0 % of sample
#
# Cluster 2
# 27.0 % of sample
#
# Cluster 3
# 9.0 % of sample
#
# Cluster 4
# 12.0 % of sample
#
# Cluster 5
# 8.0 % of sample

# %% [markdown]
# ## BCS70

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'bcs70'
study_f = sample + '_' + study
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 82.0 % of sample
#
# Cluster 1
# 4.0 % of sample
#
# Cluster 2
# 13.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms,covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 9.0 % of sample
#
# Cluster 1
# 8.0 % of sample
#
# Cluster 2 - unassigned
# 28.0 % of sample
#
# Cluster 3
# 16.0 % of sample
#
# Cluster 4
# 19.0 % of sample
#
# Cluster 5
# 15.0 % of sample
#
# Cluster 6
# 5.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 54.0 % of sample
#
# Cluster 1 - unassigned
# 44.0 % of sample
#
# Cluster 2
# 2.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 26.0 % of sample
#
# Cluster 1
# 35.0 % of sample
#
# Cluster 2
# 11.0 % of sample
#
# Cluster 3
# 7.0 % of sample
#
# Cluster 4
# 15.0 % of sample
#
# Cluster 5
# 6.0 % of sample

# %% [markdown]
# ## Twins

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'twins'
study_f = sample + '_' + study
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 64.0 % of sample
#
# Cluster 1
# 18.0 % of sample
#
# Cluster 2
# 11.0 % of sample
#
# Cluster 3
# 8.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 5.0 % of sample
#
# Cluster 1
# 11.0 % of sample
#
# Cluster 2 - unassigned
# 45.0 % of sample
#
# Cluster 3
# 6.0 % of sample
#
# Cluster 4
# 11.0 % of sample
#
# Cluster 5
# 11.0 % of sample
#
# Cluster 6
# 11.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 53.0 % of sample
#
# Cluster 1 - unassigned
# 34.0 % of sample
#
# Cluster 2
# 13.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 38.0 % of sample
#
# Cluster 1
# 22.0 % of sample
#
# Cluster 2
# 13.0 % of sample
#
# Cluster 3
# 10.0 % of sample
#
# Cluster 4
# 6.0 % of sample
#
# Cluster 5
# 12.0 % of sample

# %% [markdown]
# ## NextStep

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'nextstep'
study_f = sample + '_' + study

params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 6.0 % of sample
#
# Cluster 1 - unassigned
# 78.0 % of sample
#
# Cluster 2
# 10.0 % of sample
#
# Cluster 3
# 5.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 9.0 % of sample
#
# Cluster 1 - unassigned
# 22.0 % of sample
#
# Cluster 2
# 7.0 % of sample
#
# Cluster 3
# 28.0 % of sample
#
# Cluster 4
# 8.0 % of sample
#
# Cluster 5
# 7.0 % of sample
#
# Cluster 6
# 7.0 % of sample
#
# Cluster 7
# 5.0 % of sample
#
# Cluster 8
# 8.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 6.0 % of sample
#
# Cluster 1 - unassigned
# 83.0 % of sample
#
# Cluster 2
# 6.0 % of sample
#
# Cluster 3
# 5.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 10.0 % of sample
#
# Cluster 1 - unassigned
# 16.0 % of sample
#
# Cluster 2
# 7.0 % of sample
#
# Cluster 3
# 27.0 % of sample
#
# Cluster 4
# 13.0 % of sample
#
# Cluster 5
# 8.0 % of sample
#
# Cluster 6
# 20.0 % of sample

# %% [markdown]
# ## Track19

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'track19'
study_f = sample + '_' + study

params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 23.0 % of sample
#
# Cluster 1
# 16.0 % of sample
#
# Cluster 2
# 28.0 % of sample
#
# Cluster 3 - unassigned
# 27.0 % of sample
#
# Cluster 4
# 5.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 23.0 % of sample
#
# Cluster 1
# 19.0 % of sample
#
# Cluster 2
# 28.0 % of sample
#
# Cluster 3 - unassigned
# 30.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 10.0 % of sample
#
# Cluster 1 - unassigned
# 62.0 % of sample
#
# Cluster 2
# 8.0 % of sample
#
# Cluster 3
# 13.0 % of sample
#
# Cluster 4
# 6.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 16.0 % of sample
#
# Cluster 1
# 52.0 % of sample
#
# Cluster 2 - unassigned
# 27.0 % of sample
#
# Cluster 3
# 5.0 % of sample

# %% [markdown]
# ## NHSD 46

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %% [raw]
# study = 'nhsd46'
# study_f = sample + '_' + study
# params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
# algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# #### Agglomerative

# %% [raw]
# params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
# algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %% [raw]
# params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
# algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# #### Agglomerative

# %% [raw]
# params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
# algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# ## Pooled 7

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'pooled7'
study_f = sample + '_' + study
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 76.0 % of sample
#
# Cluster 1
# 3.0 % of sample
#
# Cluster 2
# 2.0 % of sample
#
# Cluster 3
# 2.0 % of sample
#
# Cluster 4
# 4.0 % of sample
#
# Cluster 5
# 2.0 % of sample
#
# Cluster 6
# 5.0 % of sample
#
# Cluster 7
# 3.0 % of sample
#
# Cluster 8
# 2.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 2.0 % of sample
#
# Cluster 1
# 4.0 % of sample
#
# Cluster 2
# 4.0 % of sample
#
# Cluster 3
# 36.0 % of sample
#
# Cluster 4
# 7.0 % of sample
#
# Cluster 5
# 6.0 % of sample
#
# Cluster 6
# 14.0 % of sample
#
# Cluster 7 - unassigned
# 5.0 % of sample
#
# Cluster 8
# 3.0 % of sample
#
# Cluster 9
# 13.0 % of sample
#
# Cluster 10
# 4.0 % of sample
#
# Cluster 11
# 3.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 64.0 % of sample
#
# Cluster 1
# 2.0 % of sample
#
# Cluster 2
# 7.0 % of sample
#
# Cluster 3
# 2.0 % of sample
#
# Cluster 4
# 4.0 % of sample
#
# Cluster 5
# 4.0 % of sample
#
# Cluster 6
# 6.0 % of sample
#
# Cluster 7
# 5.0 % of sample
#
# Cluster 8
# 2.0 % of sample
#
# Cluster 9
# 3.0 % of sample
#
# Cluster 10
# 2.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 4.0 % of sample
#
# Cluster 1
# 36.0 % of sample
#
# Cluster 2
# 5.0 % of sample
#
# Cluster 3
# 3.0 % of sample
#
# Cluster 4
# 2.0 % of sample
#
# Cluster 5
# 3.0 % of sample
#
# Cluster 6
# 4.0 % of sample
#
# Cluster 7
# 9.0 % of sample
#
# Cluster 8
# 20.0 % of sample
#
# Cluster 9
# 3.0 % of sample
#
# Cluster 10
# 2.0 % of sample
#
# Cluster 11 - unassigned
# 7.0 % of sample
#
# Cluster 12
# 3.0 % of sample

# %% [markdown]
# ## Pooled All

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'pooledall'
study_f = sample + '_' + study
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 42.0 % of sample
#
# Cluster 1
# 3.0 % of sample
#
# Cluster 2
# 2.0 % of sample
#
# Cluster 3
# 25.0 % of sample
#
# Cluster 4
# 4.0 % of sample
#
# Cluster 5
# 5.0 % of sample
#
# Cluster 6
# 4.0 % of sample
#
# Cluster 7
# 4.0 % of sample
#
# Cluster 8
# 2.0 % of sample
#
# Cluster 9
# 4.0 % of sample
#
# Cluster 10
# 4.0 % of sample
#
# Cluster 11
# 1.0 % of sample
#
# Cluster 12
# 1.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 7.0 % of sample
#
# Cluster 1
# 2.0 % of sample
#
# Cluster 2
# 7.0 % of sample
#
# Cluster 3
# 3.0 % of sample
#
# Cluster 4
# 2.0 % of sample
#
# Cluster 5
# 3.0 % of sample
#
# Cluster 6
# 18.0 % of sample
#
# Cluster 7
# 18.0 % of sample
#
# Cluster 8
# 18.0 % of sample
#
# Cluster 9
# 3.0 % of sample
#
# Cluster 10
# 5.0 % of sample
#
# Cluster 11
# 2.0 % of sample
#
# Cluster 12
# 7.0 % of sample
#
# Cluster 13
# 3.0 % of sample
#
# Cluster 14 - unassigned
# 1.0 % of sample
#
# Cluster 15
# 2.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 56.0 % of sample
#
# Cluster 1
# 1.0 % of sample
#
# Cluster 2
# 2.0 % of sample
#
# Cluster 3
# 5.0 % of sample
#
# Cluster 4
# 2.0 % of sample
#
# Cluster 5
# 9.0 % of sample
#
# Cluster 6
# 3.0 % of sample
#
# Cluster 7
# 4.0 % of sample
#
# Cluster 8
# 4.0 % of sample
#
# Cluster 9
# 4.0 % of sample
#
# Cluster 10
# 4.0 % of sample
#
# Cluster 11
# 2.0 % of sample
#
# Cluster 12
# 3.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 2.0 % of sample
#
# Cluster 1
# 25.0 % of sample
#
# Cluster 2
# 3.0 % of sample
#
# Cluster 3
# 6.0 % of sample
#
# Cluster 4
# 9.0 % of sample
#
# Cluster 5
# 18.0 % of sample
#
# Cluster 6
# 3.0 % of sample
#
# Cluster 7
# 3.0 % of sample
#
# Cluster 8
# 2.0 % of sample
#
# Cluster 9 - unassigned
# 7.0 % of sample
#
# Cluster 10
# 8.0 % of sample
#
# Cluster 11
# 3.0 % of sample
#
# Cluster 12
# 3.0 % of sample
#
# Cluster 13
# 4.0 % of sample
#
# Cluster 14
# 4.0 % of sample
