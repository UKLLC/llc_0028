# %% [markdown]
# # Prevalence plots: No Covid

# %% [markdown]
# This notebook contains a series of heatmaps to visualise patterns of self reported symptoms within clusters identified by DBSCAN and Agglomerative algorithms (see `llc_0028_mleval_nocovid_data_v1.ipynb`).
#
# The color scale in each figure represents the proportion of participants within each cluster that reported each symptom. Cluster sizes are all $\geq$ 5% of study size. For this sample, all studies except ALSPAC have $>$ 300 participants, therefore these values are not disclosive. Cluster sizes have not printed for ALSPAC.
#
# For the final set of plots (`pooled*`), while some clusters are less than 5% of the sample, this represents results from combining all studies into a single dataset, with over 10,000 participants. Therefore these numbers, although smaller than 5%, are also not disclosive.

# %%
# %run llc_0028_evalfuncs_syntax_v1.ipynb

# %%
os.chdir('S:/LLC_0028/data/clustering/')
sample = 'no'
covid_status=0

# %%
results = pd.read_csv(f'./results/llc_0028_best_params_ml_{sample}_v1.csv',index_col=0)

# %% [markdown]
# ## ALSPAC

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'alspac'
study_f =sample +  '_' + study

params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
#print_cluster_size(p)

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
#print_cluster_size(p)

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
#print_cluster_size(p)

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
#print_cluster_size(p)

# %% [markdown]
# ## BIB

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'bib'
study_f = sample + '_bib'

params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 65.0 % of sample
#
# Cluster 1
# 10.0 % of sample
#
# Cluster 2
# 18.0 % of sample
#
# Cluster 3
# 7.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 35.0 % of sample
#
# Cluster 1
# 10.0 % of sample
#
# Cluster 2
# 6.0 % of sample
#
# Cluster 3
# 21.0 % of sample
#
# Cluster 4
# 8.0 % of sample
#
# Cluster 5
# 11.0 % of sample
#
# Cluster 6
# 8.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 75.0 % of sample
#
# Cluster 1
# 22.0 % of sample
#
# Cluster 2
# 3.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 9.0 % of sample
#
# Cluster 1 - unassigned
# 19.0 % of sample
#
# Cluster 2
# 17.0 % of sample
#
# Cluster 3
# 34.0 % of sample
#
# Cluster 4
# 21.0 % of sample

# %% [markdown]
# ## NCDS

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'ncds'
study_f = sample + '_' + study

params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 66.0 % of sample
#
# Cluster 1
# 27.0 % of sample
#
# Cluster 2
# 7.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 12.0 % of sample
#
# Cluster 1
# 10.0 % of sample
#
# Cluster 2
# 12.0 % of sample
#
# Cluster 3
# 5.0 % of sample
#
# Cluster 4
# 9.0 % of sample
#
# Cluster 5 - unassigned
# 35.0 % of sample
#
# Cluster 6
# 7.0 % of sample
#
# Cluster 7
# 10.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 69.0 % of sample
#
# Cluster 1
# 24.0 % of sample
#
# Cluster 2
# 7.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 32.0 % of sample
#
# Cluster 1
# 14.0 % of sample
#
# Cluster 2
# 12.0 % of sample
#
# Cluster 3
# 6.0 % of sample
#
# Cluster 4
# 9.0 % of sample
#
# Cluster 5
# 10.0 % of sample
#
# Cluster 6
# 9.0 % of sample
#
# Cluster 7
# 8.0 % of sample

# %% [markdown]
# ## MCS

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'mcs'
study_f = sample + '_' + study

params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 81.0 % of sample
#
# Cluster 1
# 8.0 % of sample
#
# Cluster 2
# 5.0 % of sample
#
# Cluster 3
# 6.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 14.0 % of sample
#
# Cluster 1 - unassigned
# 26.0 % of sample
#
# Cluster 2
# 11.0 % of sample
#
# Cluster 3
# 8.0 % of sample
#
# Cluster 4
# 10.0 % of sample
#
# Cluster 5
# 10.0 % of sample
#
# Cluster 6
# 6.0 % of sample
#
# Cluster 7
# 9.0 % of sample
#
# Cluster 8
# 5.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 23.0 % of sample
#
# Cluster 1 - unassigned
# 52.0 % of sample
#
# Cluster 2
# 8.0 % of sample
#
# Cluster 3
# 11.0 % of sample
#
# Cluster 4
# 5.0 % of sample
#
# Cluster 5
# 1.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 41.0 % of sample
#
# Cluster 1 - unassigned
# 24.0 % of sample
#
# Cluster 2
# 8.0 % of sample
#
# Cluster 3
# 7.0 % of sample
#
# Cluster 4
# 11.0 % of sample
#
# Cluster 5
# 8.0 % of sample

# %% [markdown]
# ## BCS70

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'bcs70'
study_f = sample + '_' + study
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 6.0 % of sample
#
# Cluster 1 - unassigned
# 59.0 % of sample
#
# Cluster 2
# 6.0 % of sample
#
# Cluster 3
# 16.0 % of sample
#
# Cluster 4
# 7.0 % of sample
#
# Cluster 5
# 6.0 % of sample
#
# Cluster 6
# 1.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms,covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 6.0 % of sample
#
# Cluster 1
# 8.0 % of sample
#
# Cluster 2 - unassigned
# 24.0 % of sample
#
# Cluster 3
# 28.0 % of sample
#
# Cluster 4
# 10.0 % of sample
#
# Cluster 5
# 14.0 % of sample
#
# Cluster 6
# 9.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 4.0 % of sample
#
# Cluster 1 - unassigned
# 62.0 % of sample
#
# Cluster 2
# 6.0 % of sample
#
# Cluster 3
# 14.0 % of sample
#
# Cluster 4
# 7.0 % of sample
#
# Cluster 5
# 6.0 % of sample
#
# Cluster 6
# 2.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 9.0 % of sample
#
# Cluster 1
# 14.0 % of sample
#
# Cluster 2
# 8.0 % of sample
#
# Cluster 3
# 12.0 % of sample
#
# Cluster 4 - unassigned
# 15.0 % of sample
#
# Cluster 5
# 17.0 % of sample
#
# Cluster 6
# 9.0 % of sample
#
# Cluster 7
# 6.0 % of sample
#
# Cluster 8
# 11.0 % of sample

# %% [markdown]
# ## Twins

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'twins'
study_f = sample + '_' + study
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 6.0 % of sample
#
# Cluster 1
# 15.0 % of sample
#
# Cluster 2 - unassigned
# 54.0 % of sample
#
# Cluster 3
# 8.0 % of sample
#
# Cluster 4
# 5.0 % of sample
#
# Cluster 5
# 7.0 % of sample
#
# Cluster 6
# 5.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 22.0 % of sample
#
# Cluster 1
# 15.0 % of sample
#
# Cluster 2
# 5.0 % of sample
#
# Cluster 3 - unassigned
# 19.0 % of sample
#
# Cluster 4
# 16.0 % of sample
#
# Cluster 5
# 8.0 % of sample
#
# Cluster 6
# 9.0 % of sample
#
# Cluster 7
# 6.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %% [raw]
# params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
# algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]
#
# p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %% [raw]
# print_cluster_size(p)

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 33.0 % of sample
#
# Cluster 1 - unassigned
# 31.0 % of sample
#
# Cluster 2
# 7.0 % of sample
#
# Cluster 3
# 13.0 % of sample
#
# Cluster 4
# 9.0 % of sample
#
# Cluster 5
# 8.0 % of sample

# %% [markdown]
# ## NextStep

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'nextstep'
study_f = sample + '_' + study

params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 79.0 % of sample
#
# Cluster 1
# 7.0 % of sample
#
# Cluster 2
# 7.0 % of sample
#
# Cluster 3
# 7.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 17.0 % of sample
#
# Cluster 1
# 30.0 % of sample
#
# Cluster 2
# 10.0 % of sample
#
# Cluster 3 - unassigned
# 20.0 % of sample
#
# Cluster 4
# 6.0 % of sample
#
# Cluster 5
# 17.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 80.0 % of sample
#
# Cluster 1
# 7.0 % of sample
#
# Cluster 2
# 6.0 % of sample
#
# Cluster 3
# 7.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 21.0 % of sample
#
# Cluster 1
# 33.0 % of sample
#
# Cluster 2 - unassigned
# 20.0 % of sample
#
# Cluster 3
# 14.0 % of sample
#
# Cluster 4
# 12.0 % of sample

# %% [markdown]
# ## Track19

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'track19'
study_f = sample + '_' + study

params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 31.0 % of sample
#
# Cluster 1
# 8.0 % of sample
#
# Cluster 2 - unassigned
# 19.0 % of sample
#
# Cluster 3
# 16.0 % of sample
#
# Cluster 4
# 26.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 46.0 % of sample
#
# Cluster 1
# 9.0 % of sample
#
# Cluster 2 - unassigned
# 19.0 % of sample
#
# Cluster 3
# 26.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 9.0 % of sample
#
# Cluster 1
# 5.0 % of sample
#
# Cluster 2 - unassigned
# 47.0 % of sample
#
# Cluster 3
# 10.0 % of sample
#
# Cluster 4
# 13.0 % of sample
#
# Cluster 5
# 16.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 48.0 % of sample
#
# Cluster 1 - unassigned
# 35.0 % of sample
#
# Cluster 2
# 17.0 % of sample

# %% [markdown]
# ## NHSD 46

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'nhsd46'
study_f = sample + '_' + study
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 80.0 % of sample
#
# Cluster 1
# 6.0 % of sample
#
# Cluster 2
# 8.0 % of sample
#
# Cluster 3
# 6.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 8.0 % of sample
#
# Cluster 1 - unassigned
# 33.0 % of sample
#
# Cluster 2
# 5.0 % of sample
#
# Cluster 3
# 8.0 % of sample
#
# Cluster 4
# 21.0 % of sample
#
# Cluster 5
# 13.0 % of sample
#
# Cluster 6
# 6.0 % of sample
#
# Cluster 7
# 5.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 62.0 % of sample
#
# Cluster 1
# 30.0 % of sample
#
# Cluster 2
# 8.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 32.0 % of sample
#
# Cluster 1
# 7.0 % of sample
#
# Cluster 2
# 8.0 % of sample
#
# Cluster 3
# 7.0 % of sample
#
# Cluster 4
# 27.0 % of sample
#
# Cluster 5
# 8.0 % of sample
#
# Cluster 6
# 5.0 % of sample
#
# Cluster 7
# 6.0 % of sample

# %% [markdown]
# ## Pooled 7

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'pooled7'
study_f = sample + '_' + study
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 42.0 % of sample
#
# Cluster 1
# 2.0 % of sample
#
# Cluster 2
# 2.0 % of sample
#
# Cluster 3
# 20.0 % of sample
#
# Cluster 4
# 3.0 % of sample
#
# Cluster 5
# 4.0 % of sample
#
# Cluster 6
# 2.0 % of sample
#
# Cluster 7
# 5.0 % of sample
#
# Cluster 8
# 2.0 % of sample
#
# Cluster 9
# 6.0 % of sample
#
# Cluster 10
# 3.0 % of sample
#
# Cluster 11
# 4.0 % of sample
#
# Cluster 12
# 2.0 % of sample
#
# Cluster 13
# 3.0 % of sample
#
# Cluster 14
# 0.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 8.0 % of sample
#
# Cluster 1 - unassigned
# 6.0 % of sample
#
# Cluster 2
# 4.0 % of sample
#
# Cluster 3
# 5.0 % of sample
#
# Cluster 4
# 20.0 % of sample
#
# Cluster 5
# 4.0 % of sample
#
# Cluster 6
# 8.0 % of sample
#
# Cluster 7
# 2.0 % of sample
#
# Cluster 8
# 14.0 % of sample
#
# Cluster 9
# 11.0 % of sample
#
# Cluster 10
# 4.0 % of sample
#
# Cluster 11
# 9.0 % of sample
#
# Cluster 12
# 2.0 % of sample
#
# Cluster 13
# 3.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 64.0 % of sample
#
# Cluster 1
# 2.0 % of sample
#
# Cluster 2
# 7.0 % of sample
#
# Cluster 3
# 2.0 % of sample
#
# Cluster 4
# 4.0 % of sample
#
# Cluster 5
# 4.0 % of sample
#
# Cluster 6
# 6.0 % of sample
#
# Cluster 7
# 5.0 % of sample
#
# Cluster 8
# 2.0 % of sample
#
# Cluster 9
# 3.0 % of sample
#
# Cluster 10
# 2.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 9.0 % of sample
#
# Cluster 1
# 2.0 % of sample
#
# Cluster 2
# 26.0 % of sample
#
# Cluster 3
# 31.0 % of sample
#
# Cluster 4
# 4.0 % of sample
#
# Cluster 5
# 3.0 % of sample
#
# Cluster 6
# 2.0 % of sample
#
# Cluster 7
# 2.0 % of sample
#
# Cluster 8 - unassigned
# 5.0 % of sample
#
# Cluster 9
# 8.0 % of sample
#
# Cluster 10
# 2.0 % of sample
#
# Cluster 11
# 3.0 % of sample
#
# Cluster 12
# 3.0 % of sample

# %% [markdown]
# ## Pooled All

# %% [markdown]
# ### Core

# %% [markdown]
# #### DBSCAN

# %%
study = 'pooledall'
study_f = sample + '_' + study
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample, core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 31.0 % of sample
#
# Cluster 1
# 2.0 % of sample
#
# Cluster 2
# 3.0 % of sample
#
# Cluster 3
# 18.0 % of sample
#
# Cluster 4
# 2.0 % of sample
#
# Cluster 5
# 3.0 % of sample
#
# Cluster 6
# 1.0 % of sample
#
# Cluster 7
# 6.0 % of sample
#
# Cluster 8
# 1.0 % of sample
#
# Cluster 9
# 5.0 % of sample
#
# Cluster 10
# 6.0 % of sample
#
# Cluster 11
# 1.0 % of sample
#
# Cluster 12
# 7.0 % of sample
#
# Cluster 13
# 2.0 % of sample
#
# Cluster 14
# 1.0 % of sample
#
# Cluster 15
# 1.0 % of sample
#
# Cluster 16
# 8.0 % of sample
#
# Cluster 17
# 1.0 % of sample
#
# Cluster 18
# 0.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='core')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='core')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample,core=True)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 18.0 % of sample
#
# Cluster 1
# 21.0 % of sample
#
# Cluster 2
# 9.0 % of sample
#
# Cluster 3
# 5.0 % of sample
#
# Cluster 4
# 9.0 % of sample
#
# Cluster 5
# 4.0 % of sample
#
# Cluster 6
# 10.0 % of sample
#
# Cluster 7
# 2.0 % of sample
#
# Cluster 8
# 2.0 % of sample
#
# Cluster 9 - unassigned
# 1.0 % of sample
#
# Cluster 10
# 8.0 % of sample
#
# Cluster 11
# 3.0 % of sample
#
# Cluster 12
# 8.0 % of sample

# %% [markdown]
# ### Maximal

# %% [markdown]
# #### DBSCAN

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[0]
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[0]

p = plot_prevalence(study, str(params), algorithms)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0 - unassigned
# 56.0 % of sample
#
# Cluster 1
# 1.0 % of sample
#
# Cluster 2
# 2.0 % of sample
#
# Cluster 3
# 5.0 % of sample
#
# Cluster 4
# 2.0 % of sample
#
# Cluster 5
# 9.0 % of sample
#
# Cluster 6
# 3.0 % of sample
#
# Cluster 7
# 4.0 % of sample
#
# Cluster 8
# 4.0 % of sample
#
# Cluster 9
# 4.0 % of sample
#
# Cluster 10
# 4.0 % of sample
#
# Cluster 11
# 2.0 % of sample
#
# Cluster 12
# 3.0 % of sample

# %% [markdown]
# #### Agglomerative

# %%
params = results.loc[(results.study==study_f) & (results.type=='maximal')].param.iloc[1].astype(int)
algorithms = results.loc[(results.study==study_f) & (results.type=='maximal')].algorithm.iloc[1]

p = plot_prevalence(study, str(params), algorithms, covid_status, sample)

# %% [markdown]
# #### Cluster sizes

# %%
print_cluster_size(p)
# Out:
# Cluster 0
# 14.0 % of sample
#
# Cluster 1
# 22.0 % of sample
#
# Cluster 2
# 6.0 % of sample
#
# Cluster 3
# 6.0 % of sample
#
# Cluster 4
# 14.0 % of sample
#
# Cluster 5
# 3.0 % of sample
#
# Cluster 6
# 3.0 % of sample
#
# Cluster 7 - unassigned
# 7.0 % of sample
#
# Cluster 8
# 5.0 % of sample
#
# Cluster 9
# 6.0 % of sample
#
# Cluster 10
# 2.0 % of sample
#
# Cluster 11
# 3.0 % of sample
#
# Cluster 12
# 3.0 % of sample
#
# Cluster 13
# 6.0 % of sample
