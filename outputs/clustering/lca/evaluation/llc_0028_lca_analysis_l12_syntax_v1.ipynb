# %% [markdown]
# # Evaluation of Latent Class Analysis: Covid < 12 weeks ago

# %% [markdown]
# This notebook contains plots that evaluate the performance of latent class analysis (LCA). For each study, LCA has been applied to self-reported symptom data with number of classes ranging from 1 to 5.
#
# For each study, there is a plot evaluating the LCA. The size of the smallest class, as a % of sample size, is printed for each value of N to ensure the smallest class is > 5% of sample for the chosen N.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.chdir('S:/LLC_0028/data/lca_results')

# %%
def find_smallest_class(df):
    
    sc = []
    
    for col in df.columns[:-1]:
        
        sc.append(min(df[col].value_counts()))
        
    return np.array(sc)*100/sc[0]

# %%
def eval_plot(f):
    
    num2cohort = {1: 'bcs70',
                  2:'bib',
                  3: 'mcs',
                  4: 'ncds',
                  5: 'nextstep',
                  6: 'nhsd46',
                  7: 'track19',
                  8: 'twins',
                  9: 'alspac',
                 }
    
    
    dta = pd.read_csv(f, index_col=0)

    class_dta = pd.read_csv(f.split('.')[0] + '_classes.csv', index_col=0)
    
    sc = find_smallest_class(class_dta)
    print('Smallest cluster (% sample size) ',[round(v,2) for v in sc])
    
    fig,ax_list = plt.subplots(1,2, figsize=(8,4))

    ax = ax_list[0]
    ax.plot(dta.Model, dta.BIC, '-.', lw = 2, label='BIC')
    ax.plot(dta.Model, dta.AIC, '-.', lw = 2, label='AIC')
        
    ax.grid()
    ax.set_xlabel('N classes')
    ax.legend(loc='best')

    ax = ax_list[1]
    ax.plot(dta.Model, dta.entropy/dta.entropy.values[0], 'g-.', lw=2, label='Entropy')
    ax.plot(dta.Model, dta.likelihood_ratio/dta.likelihood_ratio.values[0], 'r-.', lw=2, label='LR')
        
    ax.grid()
    plt.xlabel('N classes')
    plt.legend(loc='best')
 
    f = f.split('.')[0].split('_')
    
    if f[-1] in np.char.mod('%d',np.arange(1,10)):
        
        f[-1] = num2cohort[int(f[-1])]

    fig.suptitle((' ').join(f), fontsize=16)
    plt.tight_layout()

    plt.show()

# %%
results = pd.DataFrame()

# %%
cohort2num = {'bcs70':1,
              'bib':2,
              'mcs':3,
              'ncds':4,
              'nextstep':5,
              'nhsd46':6,
              'track19':7,
              'twins':8,
              'alspac':9,
                }

# %% [markdown]
# # No covid

# %% [markdown]
# ## ALSPAC

# %%
study = 'alspac'
f = f'core_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 50.0, 50.0, 50.0, 50.0]

# %%
#results = results.append({'study': study, 'param': 2, 'type':'core','status':'nocovid'}, ignore_index=True)

# %%
f = f'maximal_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 50.0, 50.0, 50.0, 50.0]

# %%
#results = results.append({'study': study, 'param': 2, 'type':'maximal','status':'nocovid'}, ignore_index=True)

# %% [markdown]
# ## BiB

# %%
study = 'bib'
f = f'core_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 42.86, 28.57, 14.29, 14.29]

# %%
#results = results.append({'study': study, 'param': 2, 'type':'core','status':'nocovid'}, ignore_index=True)

# %%
f = f'maximal_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 42.86, 14.29, 14.29, 14.29]

# %%
#results = results.append({'study': study, 'param': 2, 'type':'maximal','status':'nocovid'}, ignore_index=True)

# %% [markdown]
# ## NCDS

# %%
study = 'ncds'
f = f'core_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 35.47, 16.86, 13.37, 12.79]

# %%
results = results.append({'study': study, 'param': 2, 'type':'core','status':'l12'}, ignore_index=True)

# %%
f = f'maximal_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 35.47, 16.86, 11.05, 12.79]

# %%
results = results.append({'study': study, 'param': 2, 'type':'maximal','status':'l12'}, ignore_index=True)

# %% [markdown]
# ## MCS

# %%
study = 'mcs'
f = f'core_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 24.09, 26.65, 13.43, 7.46]

# %%
results = results.append({'study': study, 'param': 2, 'type':'core','status':'l12'}, ignore_index=True)

# %%
f = f'maximal_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 24.09, 26.65, 13.43, 7.46]

# %%
results = results.append({'study': study, 'param': 2, 'type':'maximal','status':'l12'}, ignore_index=True)

# %% [markdown]
# ## BCS70

# %%
study = 'bcs70'
f = f'core_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 33.77, 28.51, 8.77, 11.84]

# %%
results = results.append({'study': study, 'param': 2, 'type':'core','status':'l12'}, ignore_index=True)

# %%
f = f'maximal_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 33.77, 28.51, 8.77, 9.65]

# %%
results = results.append({'study': study, 'param': 2, 'type':'maximal','status':'l12'}, ignore_index=True)

# %% [markdown]
# ## TWINS

# %%
study = 'twins'
f = f'core_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 22.73, 13.64, 4.55, 4.55]

# %%
#results = results.append({'study': study, 'param': 3, 'type':'core','status':'nocovid'}, ignore_index=True)

# %%
f = f'maximal_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 13.64, 4.55, 4.55, 4.55]

# %%
#results = results.append({'study': study, 'param': 3, 'type':'maximal','status':'nocovid'}, ignore_index=True)

# %% [markdown]
# ## NextStep

# %%
study = 'nextstep'
f = f'core_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 19.13, 9.84, 9.29, 6.56]

# %%
results = results.append({'study': study, 'param': 2, 'type':'core','status':'l12'}, ignore_index=True)

# %%
f = f'maximal_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 19.13, 6.56, 9.29, 9.29]

# %%
results = results.append({'study': study, 'param': 2, 'type':'maximal','status':'l12'}, ignore_index=True)

# %% [markdown]
# ## Track19

# %%
study = 'track19'
f = f'core_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 5.37, 6.21, 2.26, 0.56]

# %%
results = results.append({'study': study, 'param': 2, 'type':'core','status':'l12'}, ignore_index=True)

# %%
f = f'maximal_cohort_l12_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 5.08, 5.08, 2.26, 2.26]

# %%
results = results.append({'study': study, 'param': 2, 'type':'maximal','status':'l12'}, ignore_index=True)

# %% [markdown]
# ## NHSD 46

# %%
study = 'nhsd46'
f = f'core_cohort_nocovid_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 10.34, 10.46, 9.04, 7.13]

# %%
results = results.append({'study': study, 'param': 3, 'type':'core','status':'l12'}, ignore_index=True)

# %%
f = f'maximal_cohort_nocovid_{cohort2num[study]}.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 10.34, 10.46, 9.04, 7.13]

# %%
results = results.append({'study': study, 'param': 3, 'type':'maximal','status':'l12'}, ignore_index=True)

# %% [markdown]
# ## Pooled

# %%
study = 'pooled'
f = f'core_pooled_l12.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 27.37, 22.67, 12.85, 8.29]

# %%
results = results.append({'study': study, 'param': 2, 'type':'core','status':'l12'}, ignore_index=True)

# %%
f = f'maximal_pooled_l12.csv'
eval_plot(f)
# Out:
# Smallest cluster (% sample size)  [100.0, 27.09, 1.87, 1.73, 1.73]

# %%
results = results.append({'study': study, 'param': 4, 'type':'maximal','status':'l12'}, ignore_index=True)

# %%
results.to_csv('llc_0028_bestparams_lca_l12.csv')
